# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import HistGradientBoostingClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/creditcard_2023.csv')
df.head(10)
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# 5   5  0.025302 -0.140514  1.191138 -0.707979  0.430490  0.458973  0.611050
# 6   6  1.016482 -0.397181  0.497868 -0.144463  0.331022  0.629243  0.431262
# 7   7 -0.051306 -0.007194  1.139941 -0.877880  0.684668  0.714326  0.892615
# 8   8 -0.130680 -0.349547  0.425786 -0.760444  1.702777  2.324816  0.568968
# 9   9  0.058419 -0.093507  1.117270 -0.735172  0.466111  0.332371  0.683425
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
df.shape
# Out:
# (568630, 31)

# %%
#rows_with_null

df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, V1, V2, V3, V4, V5, V6, V7, V8, V9, V10, V11, V12, V13, V14, V15, V16, V17, V18, V19, V20, V21, V22, V23, V24, V25, V26, V27, V28, Amount, Class]
# Index: []
#
# [0 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
df.tail(10)
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 568620  568620 -1.604804  0.972534 -1.749894  1.920681 -1.856257 -0.219136
# 568621  568621 -0.739211  0.231882 -0.410204  0.511278  0.056859 -0.410720
# 568622  568622 -0.838047  0.362350 -0.061538  0.252811 -0.006436 -0.222957
# 568623  568623 -0.873853  0.780667 -0.418023  0.399324  0.522744  0.943413
# 568624  568624 -0.542349  0.585098 -0.547730  1.005465 -0.702046 -0.287417
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df["Class"].value_counts()
# Out:
# 0    284315
# 1    284315
# Name: Class, dtype: int64

# %%
fraud = df[df["Class"]==1]
valid = df[df["Class"]==0]

print("Fraud transaction cases {}".format(len(fraud)))
print("Valid transaction cases {}".format(len(valid)))
# Out:
# Fraud transaction cases 284315
# Valid transaction cases 284315

# %%
print("Amount details of fraud transaction")
fraud.Amount.describe()
# Out:
# Amount details of fraud transaction
# count    284315.000000
# mean      12057.601763
# std        6909.750891
# min          50.010000
# 25%        6074.640000
# 50%       12062.450000
# 75%       18033.780000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
print("Amount details of valid transaction")
valid.Amount.describe()
# Out:
# Amount details of valid transaction
# count    284315.000000
# mean      12026.313506
# std        6929.500715
# min          50.120000
# 25%        6034.540000
# 50%       11996.900000
# 75%       18040.265000
# max       24039.930000
# Name: Amount, dtype: float64

# %%
df.dropna()
# Out:
#             id        V1        V2        V3        V4        V5        V6  \
# 0            0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898
# 1            1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605
# 2            2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481
# 3            3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312
# 4            4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549
# ...        ...       ...       ...       ...       ...       ...       ...
# 568625  568625 -0.833437  0.061886 -0.899794  0.904227 -1.002401  0.481454
# 568626  568626 -0.670459 -0.202896 -0.068129 -0.267328 -0.133660  0.237148
# 568627  568627 -0.311997 -0.004095  0.137526 -0.035893 -0.042291  0.121098
# 568628  568628  0.636871 -0.516970 -0.300889 -0.144480  0.131042 -0.294148
# 568629  568629 -0.795144  0.433236 -0.649140  0.374732 -0.244976 -0.603493
#
# ...

# %% [markdown]
# ## Plotting Correlation Matrix
#
#   The correlation matrix graphicallygives us an idea of how features correlate with each other and can help us predict what features are most relevant for the prediction.

# %%
cor = df.corr()
fig = plt.figure(figsize = (12,9))
sns.heatmap(cor,vmax=8, square = True)
# Out:
# <Axes: >

# %%
  ## In the Heatmap we can see that most of the features do not correlate to other features but there are some features that either has a positive or a negative correlation with each other. For example V2 and V5 are highly negatively correlated with the feature called Amount, Also there is acorrelation with V20 and Amount This gives us a deeper understanding of the Data available to us.

# %% [markdown]
#   # Separating the X and Y values
#
#     Dividing the X and Y values

# %%
# To divide the X and Y from the dataset
X = df.drop(['Class'], axis = 1)
Y = df["Class"]
print(X.shape)
print(Y.shape)
# getting just the values for the sake of processing
# (its a numpy array with no columns)
xData = X.values
yData = Y.values
# Out:
# (568630, 30)
# (568630,)

# %% [markdown]
# # Training and Testing Data
#
#    Dividing the dataset into Two main groups. One for Training the model and the other for testing The Model's performance

# %%
X_train,X_test,y_train,y_test = train_test_split(xData,yData, test_size = 0.3 , random_state = 42)

# %% [markdown]
# # Building a Random Forest Model using scikit learn

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(X_test)

# %%
print(y_pred)
# Out:
# [1 1 0 ... 1 1 1]

# %%
from sklearn.metrics import classification_report , accuracy_score

# %%
acc = accuracy_score(y_test,y_pred)
print("Accuracy score : {}".format(acc*100))
# Out:
# Accuracy score : 99.98182766766908

# %%
print("Classification report : \n",classification_report(y_test,y_pred))
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85149
#            1       1.00      1.00      1.00     85440
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
